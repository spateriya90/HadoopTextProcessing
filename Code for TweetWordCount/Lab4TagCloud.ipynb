# %%
library(wordcloud)
require(RColorBrewer)

pal2 <- brewer.pal(8,"Accent")
# Out:
# Warning message:
# "package 'wordcloud' was built under R version 3.3.3"Loading required package: RColorBrewer

# %%
data <- read.csv("EconomyWC.csv", header = TRUE)
head(data)
# Out:
#   Word     Count
# 1 #1       2
# 2 #1k      1
# 3 #2       1
# 4 #204Econ 1
# 5 #21CL    1
# 6 #39      2

# %%
wordcloud(words=data$Word,freq=data$Count,min.freq=5, max.words = 50, random.order = FALSE,colors=pal2)
# Out:
# plot without title
